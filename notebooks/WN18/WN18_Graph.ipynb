# %%
import psycopg2 as pg
import pandas.io.sql as psql
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
from nltk.corpus import wordnet as wn

# %%
def wordnet_graph(words):
     
    """
    Construct a semantic graph and labels for a set of object categories using 
    WordNet and NetworkX. 

    Parameters: 
    ----------
     words : set
         Set of words for all the categories. 

     Returns: 
     -------
     graph : graph
         Graph object containing edges and nodes for the network. 
     labels : dict
         Dictionary of all synset labels. 
     """
     
    graph = nx.DiGraph()
    labels = {}
    seen = set()

    def recurse(s):

        """ Recursively move up semantic hierarchy and add nodes / edges """  

        if not s in seen:                               # if not seen...
            seen.add(s)                                 # add to seen
            graph.add_node(s.name)                      # add node
            labels[s.name] = s.name().split(".")[0]     # add label
            hypernyms = s.hypernyms()                   # get hypernyms

            for s1 in hypernyms:                        # for hypernyms
                graph.add_node(s1.name)                 # add node
                graph.add_edge(s.name, s1.name)         # add edge between
                recurse(s1)                             # do so until top

    # build network containing all categories          
    for word in words:                                  # for all categories
        s = wn.synset(str(word) + str('.n.01'))         # create synset            
        recurse(s)                                      # call recurse

    # return the graph and labels    
    return graph, labels

# %%
# get connected to the database
connection = pg.connect(user='scientist',
                        password='********',
                        host='127.0.01',
                        port='5432',
                        database='tensor_factorisation_wn18')

# %%
entity = psql.read_sql("SELECT * FROM entity WHERE pos_tag = 'NN'", connection)
entity.head()
# Out:
#   synset_id               name pos_tag  sense_index  \
# 0  14854262              stool      NN            2
# 1  00590383      chieftainship      NN            1
# 2  08769179             saxony      NN            1
# 3  02338145  ondatra zibethica      NN            1
# 4  11812094       rose campion      NN            1
#
#                                           definition
# 0  solid excretory product evacuated from the bowels
# 1                          the position of chieftain
# 2  an area in Germany around the upper Elbe river...
# 3  beaver-like aquatic rodent of North America wi...
# 4  an old cottage garden plant of southeastern Eu...

# %%
entity_sample = entity.sample(n=10)['name']
entity_sample
# Out:
# 3811                    crypt
# 24682                 grimace
# 32064                   works
# 15751               simarouba
# 9174     metric hundredweight
# 2015                     wing
# 30089                goldfish
# 3154              circulation
# 29187               panelling
# 27765              protrusion
# Name: name, dtype: object

# %%
categories = set()
for sample in entity_sample:
    name = '_'.join(sample.split())
    print(name)
    categories.add(name)
# Out:
# crypt
# grimace
# works
# simarouba
# metric_hundredweight
# wing
# goldfish
# circulation
# panelling
# protrusion

# %%
# create the graph and labels
graph, labels = wordnet_graph(categories)
 
print(f'labels: {labels}')
# Out:
# labels: {<bound method Synset.name of Synset('paneling.n.01')>: 'paneling', <bound method Synset.name of Synset('panel.n.01')>: 'panel', <bound method Synset.name of Synset('sheet.n.06')>: 'sheet', <bound method Synset.name of Synset('artifact.n.01')>: 'artifact', <bound method Synset.name of Synset('whole.n.02')>: 'whole', <bound method Synset.name of Synset('object.n.01')>: 'object', <bound method Synset.name of Synset('physical_entity.n.01')>: 'physical_entity', <bound method Synset.name of Synset('entity.n.01')>: 'entity', <bound method Synset.name of Synset('circulation.n.01')>: 'circulation', <bound method Synset.name of Synset('dissemination.n.01')>: 'dissemination', <bound method Synset.name of Synset('transmission.n.02')>: 'transmission', <bound method Synset.name of Synset('communication.n.01')>: 'communication', <bound method Synset.name of Synset('act.n.02')>: 'act', <bound method Synset.name of Synset('event.n.01')>: 'event', <bound method Synset.name of Synset('psychological_feature.n.01')>: 'psychological_feature', <bound method Synset.name of Synset('abstraction.n.06')>: 'abstraction', <bound method Synset.name of Synset('grimace.n.01')>: 'grimace', <bound method Synset.name of Synset('facial_expression.n.01')>: 'facial_expression', <bound method Synset.name of Synset('gesture.n.02')>: 'gesture', <bound method Synset.name of Synset('visual_communication.n.01')>: 'visual_communication', <bound method Synset.name of Synset('communication.n.02')>: 'communication', <bound method Synset.name of Synset('crypt.n.01')>: 'crypt', <bound method Synset.name of Synset('burial_chamber.n.01')>: 'burial_chamber', <bound method Synset.name of Synset('chamber.n.01')>: 'chamber', <bound method Synset.name of Synset('enclosure.n.01')>: 'enclosure', <bound method Synset.name of Synset('area.n.05')>: 'area', <bound method Synset.name of Synset('structure.n.01')>: 'structure', <bound method Synset.name of Synset('grave.n.02')>: 'grave', <bound method Synset.name of Synset('topographic_point.n.01')>: 'topographic_point', <bound method Synset.name of Synset('point.n.02')>: 'point', <bound method Synset.name of Synset('location.n.01')>: 'location', <bound method Synset.name of Synset('wing.n.01')>: 'wing', <bound method Synset.name of Synset('organ.n.01')>: 'organ', <bound method Synset.name of Synset('body_part.n.01')>: 'body_part', <bound method Synset.name of Synset('part.n.03')>: 'part', <bound method Synset.name of Synset('thing.n.12')>: 'thing', <bound method Synset.name of Synset('plant.n.01')>: 'plant', <bound method Synset.name of Synset('building_complex.n.01')>: 'building_complex', <bound method Synset.name of Synset('simarouba.n.01')>: 'simarouba', <bound method Synset.name of Synset('rosid_dicot_genus.n.01')>: 'rosid_dicot_genus', <bound method Synset.name of Synset('dicot_genus.n.01')>: 'dicot_genus', <bound method Synset.name of Synset('genus.n.02')>: 'genus', <bound method Synset.name of Synset('taxonomic_group.n.01')>: 'taxonomic_group', <bound method Synset.name of Synset('biological_group.n.01')>: 'biological_group', <bound method Synset.name of Synset('group.n.01')>: 'group', <bound method Synset.name of Synset('bulge.n.01')>: 'bulge', <bound method Synset.name of Synset('projection.n.05')>: 'projection', <bound method Synset.name of Synset('convex_shape.n.01')>: 'convex_shape', <bound method Synset.name of Synset('solid.n.03')>: 'solid', <bound method Synset.name of Synset('shape.n.02')>: 'shape', <bound method Synset.name of Synset('attribute.n.02')>: 'attribute', <bound method Synset.name of Synset('hundredweight.n.01')>: 'hundredweight', <bound method Synset.name of Synset('metric_weight_unit.n.01')>: 'metric_weight_unit', <bound method Synset.name of Synset('mass_unit.n.01')>: 'mass_unit', <bound method Synset.name of Synset('unit_of_measurement.n.01')>: 'unit_of_measurement', <bound method Synset.name of Synset('definite_quantity.n.01')>: 'definite_quantity', <bound method Synset.name of Synset('measure.n.02') ...

# %%
plt.figure(figsize=(15, 8))
# draw the graph
pos=graphviz_layout(graph)
nx.draw(graph, 
        pos=graphviz_layout(graph), 
        labels=labels,
        font_size=10,
        cmap=plt.cm.Blues,
        node_color=range(len(graph)),
        prog='dot')
plt.savefig('WN18_Graph.png', format='PNG')
plt.show()
